# %%
import time
import torch
import numpy as np
from torchvision import models

# %%
mode_list = "default reduce-overhead max-autotune".split()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # 实验一：sin 函数

# %%
def sin_func(x):
    return torch.sin(x) + torch.cos(x)


run_times = 100000
i_data = torch.tensor(1).to(device)
for mode in mode_list:
    # torch.cuda.synchronize()：在使用 CUDA 进行计算时，CUDA 操作是异步的，即 CPU 不会等待 CUDA 操作完成就会继续执行后续代码。torch.cuda.synchronize() 会阻塞 CPU 线程，直到当前设备上所有流中的所有 CUDA 核心操作都完成，确保后续记录的时间是准确的。
    torch.cuda.synchronize()
    # 编译开始的时间点
    time_0 = time.time()
    module_compiled = torch.compile(sin_func, mode=mode)
    # 再次同步 CUDA 操作，确保编译操作完成。
    torch.cuda.synchronize()
    # 记录编译结束的时间点。
    time_1 = time.time()
    # warmup
    # 热身运行：在正式进行性能测试之前，先对原始函数 sin_func 和编译后的函数 module_compiled 进行一次运行，这是因为在首次运行时，可能会有一些初始化操作（如内存分配、内核加载等），这些操作会影响后续运行时间的准确性。通过热身运行，可以让系统达到稳定状态，使后续的性能测试结果更准确。
    sin_func(i_data)
    module_compiled(i_data)
    # 同步 CUDA 操作，确保热身运行完成。
    torch.cuda.synchronize()
    # 记录热身结束的时间点。
    time_2 = time.time()
    # 运行原始函数并记录运行结束时间
    for i in range(run_times):
        sin_func(i_data)
    # 同步 CUDA 操作，确保所有调用完成。
    torch.cuda.synchronize()
    # 记录原始函数运行结束的时间点。
    time_3 = time.time()
    #  运行编译后函数并记录运行结束时间
    for i in range(run_times):
        module_compiled(i_data)
    # 同步 CUDA 操作，确保所有调用完成。
    torch.cuda.synchronize()
    # 记录编译后函数运行结束的时间点。
    time_4 = time.time()
    compile_time = time_1 - time_0  # 计算编译函数所花费的时间。
    pre_time = time_3 - time_2  # 计算编译前函数运行 run_times 次所花费的时间。
    post_time = time_4 - time_3  # 计算编译后函数运行 run_times 次所花费的时间。
    # 计算编译后函数相对于编译前函数的速度提升比例。
    speedup_ratio = (pre_time - post_time)/pre_time
    print(f"mode: {mode}, 编译耗时:{compile_time:.2f}，编译前运行耗时:{pre_time:.2f}, 编译后运行耗时:{post_time:.2f}，速度提升比例:{speedup_ratio:.2%}")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 7
#       4 i_data = torch.tensor(1).to(device)
#       5 for mode in mode_list:
#       6     # torch.cuda.synchronize()：在使用 CUDA 进行计算时，CUDA 操作是异步的，即 CPU 不会等待 CUDA 操作完成就会继续执行后续代码。torch.cuda.synchronize() 会阻塞 CPU 线程，直到当前设备上所有流中的所有 CUDA 核心操作都完成，确保后续记录的时间是准确的。
# ----> 7     torch.cuda.synchronize()
#       8     # 编译开始的时间点
#       9     time_0 = time.time()
#
# File d:\software\miniforge\envs\v3.11.6\Lib\site-packages\torch\cuda\__init__.py:952, in synchronize(device)
#     944 def synchronize(device: _device_t = None) -> None:
#     945     r"""Wait for all kernels in all streams on a CUDA device to complete.
#     946
#     947     Args:
#    (...)
#     950             if :attr:`device` is ``None`` (default).
#     951     """
# --> 952     _lazy_init()
#     953     with torch.cuda.device(device):
#     954         return torch._C._cuda_synchronize()
#
# File d:\software\miniforge\envs\v3.11.6\Lib\site-packages\torch\cuda\__init__.py:310, in _lazy_init()
#     305     raise RuntimeError(
#     306         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     307         "multiprocessing, you must use the 'spawn' start method"
#     308     )
#     309 if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 310     raise AssertionError("Torch not compiled with CUDA enabled")
#     311 if _cudart is None:
#     312     raise AssertionError(
#     313         "libcudart functions unavailable. It looks like you have a broken build?"
#     314     )
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
# 该代码的功能是 测试 PyTorch torch.compile 在不同模式下的编译时间和运行加速效果，并计算 编译前后的执行时间及速度提升比例。
# 确保定义了 device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# 确保定义了 mode_list
mode_list = ["default", "reduce-overhead", "max-autotune"]
# 关闭错误抛出，防止 torch.compile 失败导致程序中断
torch._dynamo.config.suppress_errors = True
# 计算函数


def sin_func(x):
    return torch.sin(x) + torch.cos(x)


run_times = 100000
i_data = torch.tensor(1, dtype=torch.float32, device=device)
for mode in mode_list:
    torch.cuda.synchronize()
    time_0 = time.time()
    try:
        module_compiled = torch.compile(sin_func, mode=mode)
    except Exception as e:
        print(f"模式 {mode} 编译失败: {e}")
        continue
    torch.cuda.synchronize()
    time_1 = time.time()
    # 预热
    sin_func(i_data)
    module_compiled(i_data)
    torch.cuda.synchronize()
    time_2 = time.time()
    # 编译前运行
    for i in range(run_times):
        sin_func(i_data)
    torch.cuda.synchronize()
    time_3 = time.time()
    # 编译后运行
    for i in range(run_times):
        module_compiled(i_data)
    torch.cuda.synchronize()
    time_4 = time.time()
    compile_time = time_1 - time_0
    pre_time = time_3 - time_2
    post_time = time_4 - time_3
    speedup_ratio = (pre_time - post_time) / pre_time
    print(f"mode: {mode}, 编译耗时: {compile_time:.2f}s, 编译前运行耗时: {pre_time:.2f}s, 编译后运行耗时: {post_time:.2f}s, 速度提升比例: {speedup_ratio:.2%}")
# Out:
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] WON'T CONVERT sin_func C:\Users\Hankuke.D\AppData\Local\Temp\ipykernel_10696\3860647870.py line 15
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] due to:
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1446, in _call_user_compiler
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_gm = compiler_fn(gm, example_inputs)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\__init__.py", line 2234, in __call__
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 1521, in compile_fx
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return aot_autograd(
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\backends\common.py", line 72, in __call__
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1071, in aot_module_simplified
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = dispatch_and_compile()
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1056, in dispatch_and_compile
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, _ = create_aot_dispatcher_function(
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 522, in create_aot_dispatcher_function
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _create_aot_dispatcher_function(
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 759, in _create_aot_dispatcher_function
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, fw_metadata = compiler_fn(
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                                ^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 179, in aot_dispatch_base
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fw = compiler(fw_module, updated_flat_args)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 1350, in fw_compiler_base
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _fw_compiler_base(model, example_inputs, is_inference)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 1421, in _fw_compiler_base
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return inner_compile(
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 475, in compile_fx_inner
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 85, in debug_wrapper
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 661, in _compile_fx_inner
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = FxGraphCache.load(
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\codecache.py", line 1334, in load
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = compile_fx_fn(
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 570, in codegen_and_compile
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = fx_codegen_and_compile(gm, example_inputs, **fx_kwargs)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 878, in fx_codegen_and_compile
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = graph.compile_to_fn()
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1913, in compile_to_fn
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.compile_to_module().call
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1839, in compile_to_module
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._compile_to_module()
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1845, in _compile_to_module
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                                                              ^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1780, in codegen
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.scheduler = Scheduler(self.operations)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1731, in __init__
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._init(nodes)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in _init
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in <listcomp>
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1856, in create_scheduler_node
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return SchedulerNode(self, node)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 833, in __init__
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._compute_attrs()
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 846, in _compute_attrs
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 3360, in get_backend
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.backends[device] = self.create_backend(device)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 3352, in create_backend
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     raise RuntimeError(
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1064, in __call__
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     result = self._inner_convert(
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]              ^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 526, in __call__
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile(
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 924, in _compile
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 666, in compile_inner
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile_inner(code, one_graph, hooks, transform)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_utils_internal.py", line 87, in wrapper_function
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return function(*args, **kwargs)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 699, in _compile_inner
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     out_code = transform_code_object(code, transform)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1322, in transform_code_object
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     transformations(instructions, code_options)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 219, in _fn
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return fn(*args, **kwargs)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 634, in transform
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     tracer.run()
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2796, in run
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     super().run()
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 983, in run
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     while self.step():
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]           ^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 895, in step
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.dispatch_table[inst.opcode](self, inst)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2987, in RETURN_VALUE
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._return(inst)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2972, in _return
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.output.compile_subgraph(
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1117, in compile_subgraph
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1369, in compile_and_call_fx_graph
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = self.call_user_compiler(gm)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1416, in call_user_compiler
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._call_user_compiler(gm)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1465, in _call_user_compiler
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     raise BackendCompilerFailed(self.compiler_fn, e) from e
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1446, in _call_user_compiler
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_gm = compiler_fn(gm, example_inputs)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\__init__.py", line 2234, in __call__
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 1521, in compile_fx
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return aot_autograd(
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\backends\common.py", line 72, in __call__
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1071, in aot_module_simplified
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = dispatch_and_compile()
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1056, in dispatch_and_compile
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, _ = create_aot_dispatcher_function(
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 522, in create_aot_dispatcher_function
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _create_aot_dispatcher_function(
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 759, in _create_aot_dispatcher_function
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, fw_metadata = compiler_fn(
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                                ^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 179, in aot_dispatch_base
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fw = compiler(fw_module, updated_flat_args)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 1350, in fw_compiler_base
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _fw_compiler_base(model, example_inputs, is_inference)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 1421, in _fw_compiler_base
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return inner_compile(
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 475, in compile_fx_inner
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 85, in debug_wrapper
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 661, in _compile_fx_inner
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = FxGraphCache.load(
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\codecache.py", line 1334, in load
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = compile_fx_fn(
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 570, in codegen_and_compile
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = fx_codegen_and_compile(gm, example_inputs, **fx_kwargs)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 878, in fx_codegen_and_compile
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = graph.compile_to_fn()
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1913, in compile_to_fn
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.compile_to_module().call
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1839, in compile_to_module
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._compile_to_module()
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1845, in _compile_to_module
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                                                              ^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1780, in codegen
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.scheduler = Scheduler(self.operations)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1731, in __init__
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._init(nodes)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in _init
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in <listcomp>
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1856, in create_scheduler_node
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return SchedulerNode(self, node)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 833, in __init__
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._compute_attrs()
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 846, in _compute_attrs
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 3360, in get_backend
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.backends[device] = self.create_backend(device)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 3352, in create_backend
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     raise RuntimeError(
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1064, in __call__
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     result = self._inner_convert(
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]              ^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 526, in __call__
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile(
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 924, in _compile
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 666, in compile_inner
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile_inner(code, one_graph, hooks, transform)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_utils_internal.py", line 87, in wrapper_function
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return function(*args, **kwargs)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 699, in _compile_inner
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     out_code = transform_code_object(code, transform)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1322, in transform_code_object
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     transformations(instructions, code_options)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 219, in _fn
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return fn(*args, **kwargs)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 634, in transform
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     tracer.run()
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2796, in run
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     super().run()
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 983, in run
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     while self.step():
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]           ^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 895, in step
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.dispatch_table[inst.opcode](self, inst)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2987, in RETURN_VALUE
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._return(inst)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2972, in _return
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.output.compile_subgraph(
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1117, in compile_subgraph
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1369, in compile_and_call_fx_graph
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = self.call_user_compiler(gm)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1416, in call_user_compiler
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._call_user_compiler(gm)
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1465, in _call_user_compiler
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     raise BackendCompilerFailed(self.compiler_fn, e) from e
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0311 20:18:52.497000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# mode: default, 编译耗时: 0.00s, 编译前运行耗时: 2.53s, 编译后运行耗时: 3.27s, 速度提升比例: -29.40%
# mode: reduce-overhead, 编译耗时: 0.00s, 编译前运行耗时: 2.34s, 编译后运行耗时: 3.06s, 速度提升比例: -30.48%
# mode: max-autotune, 编译耗时: 0.00s, 编译前运行耗时: 2.33s, 编译后运行耗时: 3.16s, 速度提升比例: -35.97%

# %% [markdown]
# # 实验二：resnet18

# %%
resnet18 = models.resnet18().to(device)
resnet18.eval()
fake_img = torch.randn(16, 3, 224, 224).to(device)

# %%
# 测试 torch.compile 对 ResNet18 模型的加速效果。
run_times = 100
with torch.no_grad():
    for mode in mode_list:
        torch.cuda.synchronize()
        time_0 = time.time()
        module_compiled = torch.compile(resnet18, mode=mode)
        torch.cuda.synchronize()
        time_1 = time.time()
        # warmup 非常关键！
        resnet18(fake_img)
        module_compiled(fake_img)
        #
        torch.cuda.synchronize()
        time_2 = time.time()
        for i in range(run_times):
            resnet18(fake_img)
        torch.cuda.synchronize()
        time_3 = time.time()
        for i in range(run_times):
            module_compiled(fake_img)
        torch.cuda.synchronize()
        time_4 = time.time()
        compile_time = time_1 - time_0
        pre_time = time_3 - time_2
        post_time = time_4 - time_3
        speedup_ratio = (pre_time - post_time)/pre_time
        print(
            f"mode: {mode}, 编译耗时:{compile_time:.2f}，编译前运行耗时:{pre_time:.2f}, 编译后运行耗时:{post_time:.2f}，速度提升比例:{speedup_ratio:.2%}")
# Out:
# d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py:167: UserWarning: TensorFloat32 tensor cores for float32 matrix multiplication available but not enabled. Consider setting `torch.set_float32_matmul_precision('high')` for better performance.
#   warnings.warn(
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] WON'T CONVERT forward d:\miniforge3\envs\v3.11.6\Lib\site-packages\torchvision\models\resnet.py line 284
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] due to:
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1446, in _call_user_compiler
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_gm = compiler_fn(gm, example_inputs)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\__init__.py", line 2234, in __call__
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 1521, in compile_fx
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return aot_autograd(
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\backends\common.py", line 72, in __call__
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1071, in aot_module_simplified
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = dispatch_and_compile()
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1056, in dispatch_and_compile
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, _ = create_aot_dispatcher_function(
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 522, in create_aot_dispatcher_function
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _create_aot_dispatcher_function(
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 759, in _create_aot_dispatcher_function
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, fw_metadata = compiler_fn(
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                                ^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 179, in aot_dispatch_base
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fw = compiler(fw_module, updated_flat_args)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 1350, in fw_compiler_base
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _fw_compiler_base(model, example_inputs, is_inference)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 1421, in _fw_compiler_base
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return inner_compile(
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 475, in compile_fx_inner
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 85, in debug_wrapper
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 661, in _compile_fx_inner
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = FxGraphCache.load(
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\codecache.py", line 1334, in load
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = compile_fx_fn(
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 570, in codegen_and_compile
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = fx_codegen_and_compile(gm, example_inputs, **fx_kwargs)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 878, in fx_codegen_and_compile
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = graph.compile_to_fn()
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1913, in compile_to_fn
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.compile_to_module().call
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1839, in compile_to_module
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._compile_to_module()
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1845, in _compile_to_module
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                                                              ^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1780, in codegen
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.scheduler = Scheduler(self.operations)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1731, in __init__
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._init(nodes)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in _init
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in <listcomp>
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1856, in create_scheduler_node
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return SchedulerNode(self, node)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 833, in __init__
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._compute_attrs()
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 846, in _compute_attrs
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 3360, in get_backend
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.backends[device] = self.create_backend(device)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 3352, in create_backend
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     raise RuntimeError(
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1064, in __call__
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     result = self._inner_convert(
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]              ^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 526, in __call__
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile(
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 924, in _compile
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 666, in compile_inner
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile_inner(code, one_graph, hooks, transform)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_utils_internal.py", line 87, in wrapper_function
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return function(*args, **kwargs)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 699, in _compile_inner
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     out_code = transform_code_object(code, transform)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1322, in transform_code_object
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     transformations(instructions, code_options)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 219, in _fn
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return fn(*args, **kwargs)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 634, in transform
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     tracer.run()
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2796, in run
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     super().run()
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 983, in run
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     while self.step():
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]           ^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 895, in step
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.dispatch_table[inst.opcode](self, inst)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2987, in RETURN_VALUE
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._return(inst)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2972, in _return
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.output.compile_subgraph(
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1117, in compile_subgraph
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1369, in compile_and_call_fx_graph
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = self.call_user_compiler(gm)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1416, in call_user_compiler
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._call_user_compiler(gm)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1465, in _call_user_compiler
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     raise BackendCompilerFailed(self.compiler_fn, e) from e
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1446, in _call_user_compiler
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_gm = compiler_fn(gm, example_inputs)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\__init__.py", line 2234, in __call__
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 1521, in compile_fx
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return aot_autograd(
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\backends\common.py", line 72, in __call__
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1071, in aot_module_simplified
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = dispatch_and_compile()
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1056, in dispatch_and_compile
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, _ = create_aot_dispatcher_function(
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 522, in create_aot_dispatcher_function
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _create_aot_dispatcher_function(
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 759, in _create_aot_dispatcher_function
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, fw_metadata = compiler_fn(
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                                ^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 179, in aot_dispatch_base
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fw = compiler(fw_module, updated_flat_args)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 1350, in fw_compiler_base
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _fw_compiler_base(model, example_inputs, is_inference)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 1421, in _fw_compiler_base
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return inner_compile(
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 475, in compile_fx_inner
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 85, in debug_wrapper
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 661, in _compile_fx_inner
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = FxGraphCache.load(
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\codecache.py", line 1334, in load
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = compile_fx_fn(
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 570, in codegen_and_compile
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = fx_codegen_and_compile(gm, example_inputs, **fx_kwargs)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 878, in fx_codegen_and_compile
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = graph.compile_to_fn()
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1913, in compile_to_fn
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.compile_to_module().call
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1839, in compile_to_module
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._compile_to_module()
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1845, in _compile_to_module
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                                                              ^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1780, in codegen
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.scheduler = Scheduler(self.operations)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1731, in __init__
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._init(nodes)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in _init
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in <listcomp>
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1856, in create_scheduler_node
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return SchedulerNode(self, node)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 833, in __init__
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._compute_attrs()
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 846, in _compute_attrs
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 3360, in get_backend
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.backends[device] = self.create_backend(device)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 3352, in create_backend
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     raise RuntimeError(
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1064, in __call__
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     result = self._inner_convert(
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]              ^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 526, in __call__
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile(
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 924, in _compile
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 666, in compile_inner
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile_inner(code, one_graph, hooks, transform)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_utils_internal.py", line 87, in wrapper_function
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return function(*args, **kwargs)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 699, in _compile_inner
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     out_code = transform_code_object(code, transform)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1322, in transform_code_object
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     transformations(instructions, code_options)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 219, in _fn
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return fn(*args, **kwargs)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 634, in transform
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     tracer.run()
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2796, in run
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     super().run()
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 983, in run
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     while self.step():
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]           ^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 895, in step
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.dispatch_table[inst.opcode](self, inst)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2987, in RETURN_VALUE
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._return(inst)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2972, in _return
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.output.compile_subgraph(
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1117, in compile_subgraph
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1369, in compile_and_call_fx_graph
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = self.call_user_compiler(gm)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1416, in call_user_compiler
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._call_user_compiler(gm)
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1465, in _call_user_compiler
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     raise BackendCompilerFailed(self.compiler_fn, e) from e
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0311 20:22:00.969000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] WON'T CONVERT _forward_impl d:\miniforge3\envs\v3.11.6\Lib\site-packages\torchvision\models\resnet.py line 266
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] due to:
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1446, in _call_user_compiler
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_gm = compiler_fn(gm, example_inputs)
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\__init__.py", line 2234, in __call__
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 1521, in compile_fx
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return aot_autograd(
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\backends\common.py", line 72, in __call__
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1071, in aot_module_simplified
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = dispatch_and_compile()
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1056, in dispatch_and_compile
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, _ = create_aot_dispatcher_function(
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 522, in create_aot_dispatcher_function
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _create_aot_dispatcher_function(
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.146000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 759, in _create_aot_dispatcher_function
# ...
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 85, in debug_wrapper
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 661, in _compile_fx_inner
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = FxGraphCache.load(
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\codecache.py", line 1334, in load
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = compile_fx_fn(
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 570, in codegen_and_compile
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = fx_codegen_and_compile(gm, example_inputs, **fx_kwargs)
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 878, in fx_codegen_and_compile
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = graph.compile_to_fn()
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1913, in compile_to_fn
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.compile_to_module().call
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1839, in compile_to_module
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._compile_to_module()
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1845, in _compile_to_module
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                                                              ^^^^^^^^^^^^^^
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1780, in codegen
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.scheduler = Scheduler(self.operations)
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1731, in __init__
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._init(nodes)
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in _init
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in <listcomp>
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1856, in create_scheduler_node
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return SchedulerNode(self, node)
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 833, in __init__
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._compute_attrs()
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 846, in _compute_attrs
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 3360, in get_backend
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.backends[device] = self.create_backend(device)
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 3352, in create_backend
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     raise RuntimeError(
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1064, in __call__
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     result = self._inner_convert(
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]              ^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 526, in __call__
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile(
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 924, in _compile
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 666, in compile_inner
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile_inner(code, one_graph, hooks, transform)
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_utils_internal.py", line 87, in wrapper_function
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return function(*args, **kwargs)
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 699, in _compile_inner
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     out_code = transform_code_object(code, transform)
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1322, in transform_code_object
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     transformations(instructions, code_options)
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 219, in _fn
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return fn(*args, **kwargs)
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 634, in transform
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     tracer.run()
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2796, in run
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     super().run()
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 983, in run
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     while self.step():
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]           ^^^^^^^^^^^
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 895, in step
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.dispatch_table[inst.opcode](self, inst)
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2987, in RETURN_VALUE
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._return(inst)
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2972, in _return
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.output.compile_subgraph(
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1117, in compile_subgraph
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1369, in compile_and_call_fx_graph
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = self.call_user_compiler(gm)
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1416, in call_user_compiler
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._call_user_compiler(gm)
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1465, in _call_user_compiler
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     raise BackendCompilerFailed(self.compiler_fn, e) from e
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0311 20:22:02.296000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# mode: default, 编译耗时:0.00，编译前运行耗时:1.05, 编译后运行耗时:0.79，速度提升比例:25.47%
# mode: reduce-overhead, 编译耗时:0.00，编译前运行耗时:0.79, 编译后运行耗时:0.79，速度提升比例:-0.09%
# mode: max-autotune, 编译耗时:0.00，编译前运行耗时:0.79, 编译后运行耗时:0.79，速度提升比例:-0.09%

# %% [markdown]
# # 实验三：BERT

# %%
# BertModel：这是 transformers 库中用于加载预训练 BERT 模型的类，你可以利用它开展各类自然语言处理任务，像特征提取、文本分类等。
# BertTokenizer：该类用于将文本转换为 BERT 模型能够处理的输入格式，也就是将文本分词并转换为对应的词元 ID。
from transformers import BertModel, BertTokenizer
import time
cache_dir = "./huggingface_cache"
# 此方法用于加载预训练的 BERT 模型
# bert-base-uncased'：这是模型的名称，bert-base 表示基础版本的 BERT 模型，uncased 意味着在训练时不区分大小写。
bert = BertModel.from_pretrained('bert-base-uncased', cache_dir=cache_dir)
# 该方法用于加载预训练的 BERT 分词器。
tokenizer = BertTokenizer.from_pretrained(
    'bert-base-uncased', cache_dir=cache_dir)
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
#  测试 torch.compile 对 BERT 模型推理的加速效果
# 准备一批输入数据
# 对 BERT 模型进行编译，并分别测量编译前后模型在一批输入数据上运行多次推理的时间，从而计算出速度提升比例。
# 定义了一个用于测试的输入文本
input_text = "Here is some text to encode"
# tokenizer 是之前加载的 BERT 分词器，它将输入文本转换为模型可处理的格式，return_tensors='pt' 表示返回 PyTorch 张量，padding=True 和 truncation=True 分别用于对输入进行填充和截断，以适应模型的输入要求。
inputs = tokenizer(input_text, return_tensors='pt',
                   padding=True, truncation=True)
inputs = {k: v.to(device) for k, v in inputs.items()}
bert.to(device)
bert.eval()
run_times = 100
with torch.no_grad():
    for mode in mode_list:
        # 编译
        torch.cuda.synchronize()
        time_0 = time.time()
        bert_compiled = torch.compile(bert, mode=mode)
        torch.cuda.synchronize()
        time_1 = time.time()
        # warmup 非常关键！
        bert(**inputs)
        bert_compiled(**inputs)
        torch.cuda.synchronize()
        time_2 = time.time()
        for _ in range(run_times):
            _ = bert(**inputs)
        torch.cuda.synchronize()
        time_3 = time.time()
        for _ in range(run_times):
            _ = bert_compiled(**inputs)
        torch.cuda.synchronize()
        time_4 = time.time()
        compile_time = time_1 - time_0
        pre_time = time_3 - time_2
        post_time = time_4 - time_3
        speedup_ratio = (pre_time - post_time)/pre_time
        print(
            f"mode: {mode}, 编译耗时:{compile_time:.2f}，编译前运行耗时:{pre_time:.2f}, 编译后运行耗时:{post_time:.2f}，速度提升比例:{speedup_ratio:.2%}")
# Out:
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] WON'T CONVERT forward d:\miniforge3\envs\v3.11.6\Lib\site-packages\transformers\models\bert\modeling_bert.py line 1001
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] due to:
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1446, in _call_user_compiler
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_gm = compiler_fn(gm, example_inputs)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\__init__.py", line 2234, in __call__
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 1521, in compile_fx
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return aot_autograd(
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\backends\common.py", line 72, in __call__
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1071, in aot_module_simplified
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = dispatch_and_compile()
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1056, in dispatch_and_compile
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, _ = create_aot_dispatcher_function(
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 522, in create_aot_dispatcher_function
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _create_aot_dispatcher_function(
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 759, in _create_aot_dispatcher_function
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, fw_metadata = compiler_fn(
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                                ^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 179, in aot_dispatch_base
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fw = compiler(fw_module, updated_flat_args)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 1350, in fw_compiler_base
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _fw_compiler_base(model, example_inputs, is_inference)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 1421, in _fw_compiler_base
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return inner_compile(
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 475, in compile_fx_inner
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 85, in debug_wrapper
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 661, in _compile_fx_inner
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = FxGraphCache.load(
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\codecache.py", line 1334, in load
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = compile_fx_fn(
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 570, in codegen_and_compile
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = fx_codegen_and_compile(gm, example_inputs, **fx_kwargs)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 878, in fx_codegen_and_compile
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = graph.compile_to_fn()
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1913, in compile_to_fn
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.compile_to_module().call
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1839, in compile_to_module
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._compile_to_module()
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1845, in _compile_to_module
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                                                              ^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1780, in codegen
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.scheduler = Scheduler(self.operations)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1731, in __init__
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._init(nodes)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in _init
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in <listcomp>
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1856, in create_scheduler_node
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return SchedulerNode(self, node)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 833, in __init__
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._compute_attrs()
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 846, in _compute_attrs
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 3360, in get_backend
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.backends[device] = self.create_backend(device)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 3352, in create_backend
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     raise RuntimeError(
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1064, in __call__
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     result = self._inner_convert(
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]              ^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 526, in __call__
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile(
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 924, in _compile
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 666, in compile_inner
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile_inner(code, one_graph, hooks, transform)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_utils_internal.py", line 87, in wrapper_function
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return function(*args, **kwargs)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 699, in _compile_inner
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     out_code = transform_code_object(code, transform)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1322, in transform_code_object
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     transformations(instructions, code_options)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 219, in _fn
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return fn(*args, **kwargs)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 634, in transform
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     tracer.run()
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2796, in run
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     super().run()
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 983, in run
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     while self.step():
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]           ^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 895, in step
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.dispatch_table[inst.opcode](self, inst)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2987, in RETURN_VALUE
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._return(inst)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2972, in _return
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.output.compile_subgraph(
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1142, in compile_subgraph
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.compile_and_call_fx_graph(tx, pass2.graph_output_vars(), root)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1369, in compile_and_call_fx_graph
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = self.call_user_compiler(gm)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1416, in call_user_compiler
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._call_user_compiler(gm)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1465, in _call_user_compiler
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     raise BackendCompilerFailed(self.compiler_fn, e) from e
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1446, in _call_user_compiler
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_gm = compiler_fn(gm, example_inputs)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\__init__.py", line 2234, in __call__
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 1521, in compile_fx
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return aot_autograd(
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\backends\common.py", line 72, in __call__
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1071, in aot_module_simplified
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = dispatch_and_compile()
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1056, in dispatch_and_compile
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, _ = create_aot_dispatcher_function(
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 522, in create_aot_dispatcher_function
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _create_aot_dispatcher_function(
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 759, in _create_aot_dispatcher_function
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, fw_metadata = compiler_fn(
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                                ^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 179, in aot_dispatch_base
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fw = compiler(fw_module, updated_flat_args)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 1350, in fw_compiler_base
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _fw_compiler_base(model, example_inputs, is_inference)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 1421, in _fw_compiler_base
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return inner_compile(
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 475, in compile_fx_inner
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 85, in debug_wrapper
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 661, in _compile_fx_inner
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = FxGraphCache.load(
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\codecache.py", line 1334, in load
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = compile_fx_fn(
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 570, in codegen_and_compile
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = fx_codegen_and_compile(gm, example_inputs, **fx_kwargs)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 878, in fx_codegen_and_compile
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = graph.compile_to_fn()
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1913, in compile_to_fn
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.compile_to_module().call
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1839, in compile_to_module
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._compile_to_module()
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1845, in _compile_to_module
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                                                              ^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1780, in codegen
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.scheduler = Scheduler(self.operations)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1731, in __init__
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._init(nodes)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in _init
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in <listcomp>
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1856, in create_scheduler_node
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return SchedulerNode(self, node)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 833, in __init__
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._compute_attrs()
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 846, in _compute_attrs
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 3360, in get_backend
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.backends[device] = self.create_backend(device)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 3352, in create_backend
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     raise RuntimeError(
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1064, in __call__
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     result = self._inner_convert(
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]              ^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 526, in __call__
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile(
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 924, in _compile
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 666, in compile_inner
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile_inner(code, one_graph, hooks, transform)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_utils_internal.py", line 87, in wrapper_function
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return function(*args, **kwargs)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 699, in _compile_inner
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     out_code = transform_code_object(code, transform)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1322, in transform_code_object
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     transformations(instructions, code_options)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 219, in _fn
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return fn(*args, **kwargs)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 634, in transform
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     tracer.run()
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2796, in run
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     super().run()
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 983, in run
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     while self.step():
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]           ^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 895, in step
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.dispatch_table[inst.opcode](self, inst)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2987, in RETURN_VALUE
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._return(inst)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2972, in _return
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.output.compile_subgraph(
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1142, in compile_subgraph
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.compile_and_call_fx_graph(tx, pass2.graph_output_vars(), root)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1369, in compile_and_call_fx_graph
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = self.call_user_compiler(gm)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1416, in call_user_compiler
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._call_user_compiler(gm)
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1465, in _call_user_compiler
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     raise BackendCompilerFailed(self.compiler_fn, e) from e
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0311 20:32:30.580000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] WON'T CONVERT forward d:\miniforge3\envs\v3.11.6\Lib\site-packages\transformers\models\bert\modeling_bert.py line 181
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] due to:
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1446, in _call_user_compiler
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_gm = compiler_fn(gm, example_inputs)
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\__init__.py", line 2234, in __call__
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 1521, in compile_fx
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return aot_autograd(
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\backends\common.py", line 72, in __call__
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1071, in aot_module_simplified
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = dispatch_and_compile()
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1056, in dispatch_and_compile
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, _ = create_aot_dispatcher_function(
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 522, in create_aot_dispatcher_function
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _create_aot_dispatcher_function(
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 759, in _create_aot_dispatcher_function
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, fw_metadata = compiler_fn(
# W0311 20:32:30.706000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                                ^^^^^^^^^^^^
# ...
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 661, in _compile_fx_inner
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = FxGraphCache.load(
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\codecache.py", line 1334, in load
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = compile_fx_fn(
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 570, in codegen_and_compile
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = fx_codegen_and_compile(gm, example_inputs, **fx_kwargs)
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 878, in fx_codegen_and_compile
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = graph.compile_to_fn()
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1913, in compile_to_fn
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.compile_to_module().call
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1839, in compile_to_module
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._compile_to_module()
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1845, in _compile_to_module
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                                                              ^^^^^^^^^^^^^^
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1780, in codegen
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.scheduler = Scheduler(self.operations)
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1731, in __init__
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._init(nodes)
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in _init
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in <listcomp>
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 1856, in create_scheduler_node
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return SchedulerNode(self, node)
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 833, in __init__
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._compute_attrs()
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 846, in _compute_attrs
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 3360, in get_backend
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.backends[device] = self.create_backend(device)
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 3352, in create_backend
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     raise RuntimeError(
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1064, in __call__
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     result = self._inner_convert(
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]              ^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 526, in __call__
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile(
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 924, in _compile
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 666, in compile_inner
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile_inner(code, one_graph, hooks, transform)
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_utils_internal.py", line 87, in wrapper_function
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return function(*args, **kwargs)
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 699, in _compile_inner
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     out_code = transform_code_object(code, transform)
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1322, in transform_code_object
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     transformations(instructions, code_options)
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 219, in _fn
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return fn(*args, **kwargs)
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 634, in transform
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     tracer.run()
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2796, in run
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     super().run()
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 983, in run
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     while self.step():
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]           ^^^^^^^^^^^
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 895, in step
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.dispatch_table[inst.opcode](self, inst)
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2987, in RETURN_VALUE
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._return(inst)
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2972, in _return
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.output.compile_subgraph(
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1117, in compile_subgraph
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1369, in compile_and_call_fx_graph
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = self.call_user_compiler(gm)
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1416, in call_user_compiler
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._call_user_compiler(gm)
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1465, in _call_user_compiler
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     raise BackendCompilerFailed(self.compiler_fn, e) from e
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0311 20:32:34.532000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# mode: default, 编译耗时:0.00，编译前运行耗时:0.76, 编译后运行耗时:0.62，速度提升比例:18.03%
# d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\cuda\graphs.py:84: UserWarning: The CUDA Graph is empty. This usually means that the graph was attempted to be captured on wrong device or stream. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\cuda\CUDAGraph.cpp:209.)
#   super().capture_end()
# mode: reduce-overhead, 编译耗时:0.00，编译前运行耗时:0.52, 编译后运行耗时:0.86，速度提升比例:-66.98%
# d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\cuda\graphs.py:84: UserWarning: The CUDA Graph is empty. This usually means that the graph was attempted to be captured on wrong device or stream. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\cuda\CUDAGraph.cpp:209.)
#   super().capture_end()
# mode: max-autotune, 编译耗时:0.00，编译前运行耗时:0.47, 编译后运行耗时:0.84，速度提升比例:-77.71%

# %% [markdown]
# # 实验四 numpy

# %%
# 这段代码的功能是 测试 torch.compile 对 PyTorch 计算函数的加速效果
run_times = 100


def numpy_fn2(X: np.ndarray, Y: np.ndarray) -> np.ndarray:
    return np.sum(X[:, :, None] * Y[:, None, :], axis=(-2, -1))


def numpy_fn(X: np.ndarray, Y: np.ndarray) -> np.ndarray:
    # Step 1: Normalize the input arrays to have zero mean and unit variance
    X_mean, X_std = X.mean(axis=0), X.std(axis=0)
    Y_mean, Y_std = Y.mean(axis=0), Y.std(axis=0)
    # Avoid division by zero in case of zero standard deviation
    X_std[X_std == 0] = 1
    Y_std[Y_std == 0] = 1
    X_normalized = (X - X_mean) / X_std
    Y_normalized = (Y - Y_mean) / Y_std
    # Step 2: Perform the tensor product followed by sum over last two dimensions
    intermediate_result = np.sum(
        X_normalized[:, :, None] * Y_normalized[:, None, :], axis=(-2, -1))
    # Step 3: Apply thresholding to clip values outside of [-1, 1]
    # intermediate_result 是一个 NumPy 数组，-1 为最小值，1 是最大值。np.clip 会将 intermediate_result 数组中小于 -1 的元素置为 -1，大于 1 的元素置为 1，处于 -1 和 1 之间的元素保持不变。
    intermediate_result = np.clip(intermediate_result, -1, 1)
    # Step 4: Apply exponential function for non-linearity
    result = np.exp(intermediate_result)
    # Step 5: Add a small regularization term to avoid overfitting
    regularization_term = 0.001 * \
        np.sum(X_normalized ** 2 + Y_normalized ** 2, axis=1)
    result += regularization_term
    return result


x = np.random.randn(1024, 640)
y = np.random.randn(1024, 640)
for mode in mode_list:
    torch.cuda.synchronize()
    time_0 = time.time()
    numpy_fn_compiled = torch.compile(numpy_fn, mode=mode)
    torch.cuda.synchronize()
    time_1 = time.time()
    # warmup 非常关键！
    numpy_fn(x, y)
    numpy_fn_compiled(x, y)
    #
    torch.cuda.synchronize()
    time_2 = time.time()
    for i in range(run_times):
        numpy_fn(x, y)
    torch.cuda.synchronize()
    time_3 = time.time()
    for i in range(run_times):
        numpy_fn_compiled(x, y)
    torch.cuda.synchronize()
    time_4 = time.time()
    compile_time = time_1 - time_0
    pre_time = time_3 - time_2
    post_time = time_4 - time_3
    speedup_ratio = (pre_time - post_time)/pre_time
    print(f"mode: {mode}, 编译耗时:{compile_time:.2f}，编译前运行耗时:{pre_time:.2f}, 编译后运行耗时:{post_time:.2f}，速度提升比例:{speedup_ratio:.2%}")
# Out:
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] WON'T CONVERT numpy_fn C:\Users\Hankuke.D\AppData\Local\Temp\ipykernel_10696\778857968.py line 4
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] due to:
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\cpp_builder.py", line 130, in check_compiler_exist_windows
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     subprocess.check_output([compiler, "/help"], stderr=subprocess.STDOUT)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\subprocess.py", line 466, in check_output
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\subprocess.py", line 548, in run
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     with Popen(*popenargs, **kwargs) as process:
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\subprocess.py", line 1026, in __init__
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._execute_child(args, executable, preexec_fn, close_fds,
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\subprocess.py", line 1538, in _execute_child
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] FileNotFoundError: [WinError 2] 系统找不到指定的文件。
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1446, in _call_user_compiler
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_gm = compiler_fn(gm, example_inputs)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\__init__.py", line 2234, in __call__
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 1521, in compile_fx
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return aot_autograd(
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\backends\common.py", line 72, in __call__
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1071, in aot_module_simplified
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = dispatch_and_compile()
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1056, in dispatch_and_compile
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, _ = create_aot_dispatcher_function(
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 522, in create_aot_dispatcher_function
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _create_aot_dispatcher_function(
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 759, in _create_aot_dispatcher_function
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, fw_metadata = compiler_fn(
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                                ^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 179, in aot_dispatch_base
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fw = compiler(fw_module, updated_flat_args)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 1350, in fw_compiler_base
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _fw_compiler_base(model, example_inputs, is_inference)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 1421, in _fw_compiler_base
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return inner_compile(
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 475, in compile_fx_inner
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 85, in debug_wrapper
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 661, in _compile_fx_inner
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = FxGraphCache.load(
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\codecache.py", line 1334, in load
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = compile_fx_fn(
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 570, in codegen_and_compile
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = fx_codegen_and_compile(gm, example_inputs, **fx_kwargs)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 878, in fx_codegen_and_compile
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = graph.compile_to_fn()
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1913, in compile_to_fn
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.compile_to_module().call
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1839, in compile_to_module
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._compile_to_module()
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1845, in _compile_to_module
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                                                              ^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1784, in codegen
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.scheduler.codegen()
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 3383, in codegen
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._codegen()
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 3461, in _codegen
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.get_backend(device).codegen_node(node)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\codegen\cpp.py", line 4464, in codegen_node
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.codegen_outer_loop_node(node)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\codegen\cpp.py", line 4438, in codegen_outer_loop_node
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     if not try_outer_loop_fusion_with_local_buf(node):
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\codegen\cpp.py", line 4413, in try_outer_loop_fusion_with_local_buf
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     cpp_kernel_proxy = CppKernelProxy(kernel_group)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\codegen\cpp.py", line 3466, in __init__
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.picked_vec_isa: cpu_vec_isa.VecISA = cpu_vec_isa.pick_vec_isa()
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                                               ^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 360, in pick_vec_isa
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     _valid_vec_isa_list: List[VecISA] = valid_vec_isa_list()
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                                         ^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 350, in valid_vec_isa_list
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     if all(flag in _cpu_supported_x86_isa for flag in str(isa).split()) and isa:
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 148, in __bool__
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.check_build(VecISA._avx_code)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 101, in check_build
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     extra=_get_isa_dry_compile_fingerprint(self._arch_flags),
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 27, in _get_isa_dry_compile_fingerprint
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiler_info = get_compiler_version_info(get_cpp_compiler())
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                                               ^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\cpp_builder.py", line 144, in get_cpp_compiler
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     check_compiler_exist_windows(compiler)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\cpp_builder.py", line 135, in check_compiler_exist_windows
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     raise RuntimeError(f"Compiler: {compiler} is not found.") from exc
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Compiler: cl is not found.
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1064, in __call__
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     result = self._inner_convert(
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]              ^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 526, in __call__
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile(
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 924, in _compile
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 666, in compile_inner
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile_inner(code, one_graph, hooks, transform)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_utils_internal.py", line 87, in wrapper_function
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return function(*args, **kwargs)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 699, in _compile_inner
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     out_code = transform_code_object(code, transform)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1322, in transform_code_object
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     transformations(instructions, code_options)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 219, in _fn
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return fn(*args, **kwargs)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 634, in transform
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     tracer.run()
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2796, in run
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     super().run()
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 983, in run
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     while self.step():
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]           ^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 895, in step
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.dispatch_table[inst.opcode](self, inst)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2987, in RETURN_VALUE
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._return(inst)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2972, in _return
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.output.compile_subgraph(
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1142, in compile_subgraph
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.compile_and_call_fx_graph(tx, pass2.graph_output_vars(), root)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1369, in compile_and_call_fx_graph
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = self.call_user_compiler(gm)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1416, in call_user_compiler
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._call_user_compiler(gm)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1465, in _call_user_compiler
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     raise BackendCompilerFailed(self.compiler_fn, e) from e
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Compiler: cl is not found.
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\cpp_builder.py", line 130, in check_compiler_exist_windows
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     subprocess.check_output([compiler, "/help"], stderr=subprocess.STDOUT)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\subprocess.py", line 466, in check_output
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\subprocess.py", line 548, in run
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     with Popen(*popenargs, **kwargs) as process:
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\subprocess.py", line 1026, in __init__
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._execute_child(args, executable, preexec_fn, close_fds,
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\subprocess.py", line 1538, in _execute_child
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] FileNotFoundError: [WinError 2] 系统找不到指定的文件。
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1446, in _call_user_compiler
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_gm = compiler_fn(gm, example_inputs)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\__init__.py", line 2234, in __call__
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 1521, in compile_fx
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return aot_autograd(
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\backends\common.py", line 72, in __call__
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1071, in aot_module_simplified
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = dispatch_and_compile()
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1056, in dispatch_and_compile
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, _ = create_aot_dispatcher_function(
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 522, in create_aot_dispatcher_function
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _create_aot_dispatcher_function(
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\aot_autograd.py", line 759, in _create_aot_dispatcher_function
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, fw_metadata = compiler_fn(
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                                ^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 179, in aot_dispatch_base
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fw = compiler(fw_module, updated_flat_args)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 1350, in fw_compiler_base
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _fw_compiler_base(model, example_inputs, is_inference)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 1421, in _fw_compiler_base
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return inner_compile(
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 475, in compile_fx_inner
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 85, in debug_wrapper
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 661, in _compile_fx_inner
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = FxGraphCache.load(
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\codecache.py", line 1334, in load
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = compile_fx_fn(
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 570, in codegen_and_compile
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = fx_codegen_and_compile(gm, example_inputs, **fx_kwargs)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\compile_fx.py", line 878, in fx_codegen_and_compile
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = graph.compile_to_fn()
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1913, in compile_to_fn
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.compile_to_module().call
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1839, in compile_to_module
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._compile_to_module()
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1845, in _compile_to_module
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                                                              ^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\graph.py", line 1784, in codegen
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.scheduler.codegen()
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 3383, in codegen
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._codegen()
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\scheduler.py", line 3461, in _codegen
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.get_backend(device).codegen_node(node)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\codegen\cpp.py", line 4464, in codegen_node
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.codegen_outer_loop_node(node)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\codegen\cpp.py", line 4438, in codegen_outer_loop_node
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     if not try_outer_loop_fusion_with_local_buf(node):
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\codegen\cpp.py", line 4413, in try_outer_loop_fusion_with_local_buf
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     cpp_kernel_proxy = CppKernelProxy(kernel_group)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\codegen\cpp.py", line 3466, in __init__
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.picked_vec_isa: cpu_vec_isa.VecISA = cpu_vec_isa.pick_vec_isa()
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                                               ^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 360, in pick_vec_isa
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     _valid_vec_isa_list: List[VecISA] = valid_vec_isa_list()
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                                         ^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 350, in valid_vec_isa_list
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     if all(flag in _cpu_supported_x86_isa for flag in str(isa).split()) and isa:
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 148, in __bool__
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.check_build(VecISA._avx_code)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 101, in check_build
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     extra=_get_isa_dry_compile_fingerprint(self._arch_flags),
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\cpu_vec_isa.py", line 27, in _get_isa_dry_compile_fingerprint
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiler_info = get_compiler_version_info(get_cpp_compiler())
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                                               ^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\cpp_builder.py", line 144, in get_cpp_compiler
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     check_compiler_exist_windows(compiler)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_inductor\cpp_builder.py", line 135, in check_compiler_exist_windows
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     raise RuntimeError(f"Compiler: {compiler} is not found.") from exc
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Compiler: cl is not found.
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1064, in __call__
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     result = self._inner_convert(
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]              ^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 526, in __call__
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile(
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 924, in _compile
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 666, in compile_inner
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile_inner(code, one_graph, hooks, transform)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_utils_internal.py", line 87, in wrapper_function
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return function(*args, **kwargs)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 699, in _compile_inner
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     out_code = transform_code_object(code, transform)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1322, in transform_code_object
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     transformations(instructions, code_options)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 219, in _fn
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return fn(*args, **kwargs)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\convert_frame.py", line 634, in transform
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     tracer.run()
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2796, in run
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     super().run()
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 983, in run
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     while self.step():
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]           ^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 895, in step
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.dispatch_table[inst.opcode](self, inst)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2987, in RETURN_VALUE
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self._return(inst)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2972, in _return
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.output.compile_subgraph(
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1142, in compile_subgraph
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     self.compile_and_call_fx_graph(tx, pass2.graph_output_vars(), root)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1369, in compile_and_call_fx_graph
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = self.call_user_compiler(gm)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1416, in call_user_compiler
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._call_user_compiler(gm)
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]   File "d:\miniforge3\envs\v3.11.6\Lib\site-packages\torch\_dynamo\output_graph.py", line 1465, in _call_user_compiler
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]     raise BackendCompilerFailed(self.compiler_fn, e) from e
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Compiler: cl is not found.
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0311 20:33:15.855000 10696 site-packages\torch\_dynamo\convert_frame.py:1125]
# mode: default, 编译耗时:0.00，编译前运行耗时:124.91, 编译后运行耗时:135.04，速度提升比例:-8.11%
